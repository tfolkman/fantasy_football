# %%
import pandas as pd
import numpy as np

# %%
raw_data = pd.read_json("../get_rankings/data/rankings_list.json")

# %% [markdown]
# ##Number of times position shows up

# %%
raw_data.position.value_counts()
# Out:
# RB    113
# WR    103
# TE     35
# QB     32
# K      19
# D      18
# dtype: int64

# %% [markdown]
# ##Metrics on score by position
# Looks like kickers score a lot, but almost no variance. Can see why RB's get taken first. Highest varience, so don't want to get stuck with a bad one

# %%
raw_data.groupby("position").points.mean().order(ascending=False)
# Out:
# position
# QB    245.050000
# K     132.947368
# D     114.333333
# WR     98.866990
# RB     82.410619
# TE     79.620000
# Name: points, dtype: float64

# %%
raw_data.groupby("position").points.std().order(ascending=False)
# Out:
# position
# RB    68.318816
# QB    50.485654
# WR    46.053046
# TE    29.101211
# D     22.857616
# K      5.641844
# Name: points, dtype: float64

# %% [markdown]
# ##ADP
# Lets use these counts for my baseline

# %%
adp = pd.read_csv("../get_rankings/data/adp.csv")

# %%
adp.head()
# Out:
#     ADP  Overall             Name Position Team  Times Drafted  Bye
# 0  1.02      2.1  Adrian Peterson       RB  MIN            254    5
# 1  1.03      2.5      LeVeon Bell       RB  PIT            127   11
# 2  1.04      3.7       Eddie Lacy       RB   GB            295    7
# 3  1.04      3.9   Jamaal Charles       RB   KC            160    9
# 4  1.05      5.1   Marshawn Lynch       RB  SEA            184    9

# %%
adp.Position.value_counts()
# Out:
# WR     61
# RB     57
# QB     20
# TE     17
# DEF    11
# PK      6
# dtype: int64

# %% [markdown]
# ##Calculate Added Value

# %%
positions = ['WR', 'RB', 'QB', 'TE', 'D', 'K']
baseline = [61, 57, 20, 17, 12, 12]

# %%
def get_adj_points(pos, max_n):
    position_data = raw_data[raw_data.position == pos].sort("points", ascending=False)
    position_data = position_data.set_index(np.arange(position_data.shape[0]))
    position_data = position_data[position_data.index < max_n]
    position_data['value_adj_points'] = position_data.points - position_data.iloc[max_n - 1].points
    return position_data

# %%
all_adj = []
for i in range(len(positions)):
    all_adj.append(get_adj_points(positions[i], baseline[i]))

# %%
all_adj_df = pd.concat(all_adj)
all_adj_df = all_adj_df.sort("value_adj_points", ascending=False)
all_adj_df.head()
# Out:
#               name  points position team  value_adj_points
# 0       Eddie Lacy   232.7       RB   GB             165.5
# 1  Adrian Peterson   222.6       RB  Min             155.4
# 2   Jamaal Charles   218.7       RB   KC             151.5
# 3    C.J. Anderson   218.6       RB  Den             151.4
# 4   Marshawn Lynch   216.6       RB  Sea             149.4

# %% [markdown]
# ##Merge on ADP

# %%
adp_sub = adp[['ADP', 'Name', 'Bye']]

# %%
final_df = pd.merge(all_adj_df, adp_sub, left_on='name', right_on='Name', how='left')

# %%
final_df
# Out:
#                         name  points position      team  value_adj_points  \
# 0                 Eddie Lacy   232.7       RB        GB             165.5
# 1            Adrian Peterson   222.6       RB       Min             155.4
# 2             Jamaal Charles   218.7       RB        KC             151.5
# 3              C.J. Anderson   218.6       RB       Den             151.4
# 4             Marshawn Lynch   216.6       RB       Sea             149.4
# 5               Le'Veon Bell   211.5       RB       Pit             144.3
# 6               LeSean McCoy   205.5       RB       Buf             138.3
# 7             DeMarco Murray   203.6       RB       Phi             136.4
# 8                Jeremy Hill   201.6       RB       Cin             134.4
# 9                 Matt Forte   200.4       RB       Chi             133.2
# 10              Lamar Miller   192.5       RB       Mia             125.3
# 11             Antonio Brown   209.1       WR       Pit             122.5
# 12               Carlos Hyde   186.5       RB        SF             119.3
# 13            Justin Forsett   182.4       RB       Bal             115.2
# 14               Mark Ingram   179.6       RB        NO             112.4
# 15          Demaryius Thomas   196.0       WR       Den             109.4
# 16                Dez Bryant   194.0       WR       Dal             107.4
# 17                Frank Gore   172.5       RB       Ind             105.3
# 18             Arian Foster*   172.4       RB       Hou             105.2
# 19               Todd Gurley   170.4       RB       StL             103.2
# 20         Odell Beckham Jr.   189.0       WR       NYG             102.4
# 21            Calvin Johnson   188.0       WR       Det             101.4
# 22             Alfred Morris   168.5       RB       Wsh             101.3
# 23               Julio Jones   187.1       WR       Atl             100.5
# 24           Latavius Murray   164.8       RB       Oak              97.6
# 25          Jonathan Stewart   164.4       RB       Car              97.2
# 26             Melvin Gordon   163.3       RB        SD              96.1
# 27                A.J. Green   182.1       WR       Cin              95.5
# 28              Randall Cobb   178.0       WR        GB              91.4
# 29            Rob Gronkowski   168.0       TE        NE              86.5
# ..                       ...     ...      ...       ...               ...
# 149            Larry Donnell    87.9       TE       NYG               6.4
# 150           Adam Vinatieri   139.0        K       Ind               6.0
# 151             Lance Dunbar    72.9       RB       Dal               5.7
# 152            Justin Tucker   138.0        K       Bal               5.0
# 153           Ronnie Hillman    72.2       RB       Den               5.0
# 154                   Ravens   109.0        D    Ravens               5.0
# 155              Victor Cruz    91.0       WR       NYG               4.4
# 156              Matt Bryant   137.0        K       Atl               4.0
# 157                  Packers   108.0        D   Packers               4.0
# 158           Markus Wheaton    90.4       WR       Pit               3.8
# 159              Jordan Reed    85.1       TE       Wsh               3.6
# 160             Owen Daniels    84.9       TE       Den               3.4
# 161               Jay Cutler   241.6       QB       Chi               3.3
# 162        Teddy Bridgewater   241.4       QB       Min               3.1
# 163              Matt Prater   136.0        K       Det               3.0
# 164               Dan Bailey   136.0        K       Dal               3.0
# 165             Tyler Eifert    84.5       TE       Cin               3.0
# 166              Kenny Britt    88.0       WR       StL               1.4
# 167             Heath Miller    82.9       TE       Pit               1.4
# 168            Caleb Sturgis   134.0        K       Mia               1.0
# 169            Dan Carpenter   134.0        K       Buf               1.0
# 170               Eric Ebron    82.5       TE       Det               1.0
# 171              Cody Parkey   134.0        K       Phi               1.0
# 172             Mason Crosby   134.0        K        GB               1.0
# 173               Alex Smith   238.3       QB        KC               0.0
# 174                 Panthers   104.0        D  Panthers               0.0
# 175            Ty Montgomery    86.6       WR        GB               0.0
# 176  Austin Seferian-Jenkins    81.5       TE        TB               0.0
# 177          Denard Robinson    67.2       RB       Jac               0.0
# 178              Blair Walsh   133.0        K       Min               0.0
#
#        ADP               Name  Bye
# 0     1.04         Eddie Lacy    7
# 1     1.02    Adrian Peterson    5
# 2     1.04     Jamaal Charles    9
# 3      NaN                NaN  NaN
# 4     1.05     Marshawn Lynch    9
# 5      NaN                NaN  NaN
# 6     2.07       LeSean McCoy    8
# 7     1.12     DeMarco Murray    8
# 8     1.10        Jeremy Hill    7
# 9     2.01         Matt Forte    7
# 10    2.10       Lamar Miller    5
# 11    1.06      Antonio Brown   11
# 12    3.12        Carlos Hyde   10
# 13    2.08     Justin Forsett    9
# 14    3.05        Mark Ingram   11
# 15    1.11   Demaryius Thomas    7
# 16    1.09         Dez Bryant    6
# 17    3.03         Frank Gore   10
# 18     NaN                NaN  NaN
# 19    5.06        Todd Gurley    6
# 20     NaN                NaN  NaN
# 21    2.03     Calvin Johnson    9
# 22    3.10      Alfred Morris    8
# 23    1.08        Julio Jones   10
# 24    3.08    Latavius Murray    6
# 25    5.01   Jonathan Stewart    5
# 26    4.03      Melvin Gordon   10
# 27    2.06         A.J. Green    7
# 28    2.07       Randall Cobb    7
# 29    2.02     Rob Gronkowski    4
# ..     ...                ...  ...
# 149    NaN                NaN  NaN
# 150  13.05     Adam Vinatieri   10
# 151    NaN                NaN  NaN
# 152    NaN                NaN  NaN
# 153  10.02     Ronnie Hillman    7
# 154    NaN                NaN  NaN
# 155   7.10        Victor Cruz   11
# 156    NaN                NaN  NaN
# 157    NaN                NaN  NaN
# 158   8.05     Markus Wheaton   11
# 159    NaN                NaN  NaN
# 160   7.12       Owen Daniels    7
# 161  13.01         Jay Cutler    7
# 162  11.02  Teddy Bridgewater    5
# 163    NaN                NaN  NaN
# 164  14.08         Dan Bailey    6
# 165   9.05       Tyler Eifert    7
# 166    NaN                NaN  NaN
# 167    NaN                NaN  NaN
# 168    NaN                NaN  NaN
# 169    NaN                NaN  NaN
# 170    NaN                NaN  NaN
# 171  14.01        Cody Parkey    8
# 172  14.08       Mason Crosby    7
# 173    NaN                NaN  NaN
# 174    NaN                NaN  NaN
# 175  13.01      Ty Montgomery    7
# 176    NaN                NaN  NaN
# 177  13.12    Denard Robinson    8
# 178    NaN                NaN  NaN
#
# [179 rows x 8 columns]
